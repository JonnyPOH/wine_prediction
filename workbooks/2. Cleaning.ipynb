# %%
import pandas as pd
import os

# Load the dataset
os.chdir("..")
data_path = 'datasets'
df = pd.read_csv(os.path.join(data_path, 'wine_quality_1000.csv'))

# Display basic information about the dataset
df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0       87131      US  Very good Dry Creek Zin, robust and dry and sp...
# 1       57952  France  A very herbaceous character makes this wine se...
# 2       96046      US  A little simple and easy, but there's a wealth...
# 3       31920      US  From a dry-farmed vineyard and treated to wild...
# 4        6091      US  From a site near Annapolis, this wine shows a ...
#
#    points  price                     variety
# 0      89   25.0                   Zinfandel
# 1      84   20.0  Bordeaux-style White Blend
# 2      84   19.0                        Rosé
# 3      88   38.0                Petite Sirah
# 4      91   62.0                  Pinot Noir

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
from nltk.corpus import stopwords
import string
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize

def clean (text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, ' ') # Remove Punctuation
    lowercased = text.lower() # Lower Case
    tokenized = word_tokenize(lowercased) # Tokenize
    words_only = [word for word in tokenized if word.isalpha()] # Remove numbers
    stop_words = set(stopwords.words('english')) # Make stopword list
    without_stopwords = [word for word in words_only if not word in stop_words] # Remove Stop Words
    lemma=WordNetLemmatizer() # Initiate Lemmatizer
    lemmatized = [lemma.lemmatize(word) for word in without_stopwords] # Lemmatize
    cleaned = ' '.join(lemmatized) # Join back to a string
    return cleaned

# Apply to all texts
df['description'] = df.description.apply(clean)
df['variety'] = df.variety.apply(clean)

df.head()
# Out:
#   country                                        description  points  price  \
# 0      US  good dry creek zin robust dry spicy really get...      89   25.0
# 1  France  herbaceous character make wine seem rather thi...      84   20.0
# 2      US  little simple easy wealth raspberry strawberry...      84   19.0
# 3      US  dry farmed vineyard treated wild yeast minimal...      88   38.0
# 4      US  site near annapolis wine show preponderance da...      91   62.0
#
#                       variety
# 0                   zinfandel
# 1  bordeaux style white blend
# 2                        rosé
# 3                petite sirah
# 4                  pinot noir

# %%
df.to_csv('datasets/wine_quality_cleaned.csv')
